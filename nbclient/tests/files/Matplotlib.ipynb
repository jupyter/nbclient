# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
x = np.arange(10)
y = x**2
plt.plot(x, y)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
